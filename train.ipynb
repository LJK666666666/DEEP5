# %%
# !python train_datasets_used.py --model ultralytics/yolo11s.pt
# Out:
# Ultralytics 8.3.240 🚀 Python-3.11.5 torch-2.9.1+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81154MiB)
# ...

# %%
# !python train_datasets_used.py --model runs/detect/datasets_used_train/weights/last.pt --epochs 20
# Out:
# Ultralytics 8.3.240 🚀 Python-3.11.5 torch-2.9.1+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81154MiB)
# ...
